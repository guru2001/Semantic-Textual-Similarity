# %%
import pickle as pkl

import scikitplot as skplt

# %%
bert_quora_act = pkl.load(open('pickle_old/bert_actual_quora', 'rb'))
bert_quora_pred = pkl.load(open('pickle_old/bert_predicted_quora', 'rb'))

# %%
skplt.metrics.plot_confusion_matrix(bert_quora_act, bert_quora_pred)

# %%
bert_snli_act = pkl.load(open('pickle_old/bert_actual_snli', 'rb'))
bert_snli_pred = pkl.load(open('pickle_old/bert_predicted_snli', 'rb'))

# %%
skplt.metrics.plot_confusion_matrix(bert_snli_act, bert_snli_pred)

# %%
xlnet_quora_act = pkl.load(open('pickle_old/xlnet_actual_quora', 'rb'))
xlnet_quora_pred = pkl.load(open('pickle_old/xlnet_predicted_quora', 'rb'))

# %%
skplt.metrics.plot_confusion_matrix(xlnet_quora_act, xlnet_quora_pred)

# %%
xlnet_snli_act = pkl.load(open('pickle_old/xlnet_actual_snli', 'rb'))
xlnet_snli_pred = pkl.load(open('pickle_old/xlnet_pred_snli', 'rb'))

# %%
skplt.metrics.plot_confusion_matrix(xlnet_snli_act, xlnet_snli_pred)

# %%
roberta_quora_act = pkl.load(open('pickle_old/roberta_actual_quora', 'rb'))
roberta_quora_pred = pkl.load(open('pickle_old/roberta_predicted_quora', 'rb'))

# %%
skplt.metrics.plot_confusion_matrix(roberta_quora_act, roberta_quora_pred)

# %%
roberta_snli_act = pkl.load(open('pickle_old/roberta_actual_snli', 'rb'))
roberta_snli_pred = pkl.load(open('pickle_old/roberta_pred_snli', 'rb'))

# %%
skplt.metrics.plot_confusion_matrix(roberta_snli_act, roberta_snli_pred)
